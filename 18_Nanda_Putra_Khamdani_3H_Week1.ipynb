# %% [markdown]
# <a href="https://colab.research.google.com/github/putrakhamdani16/Dasar-Program-Semester-1/blob/main/18_Nanda_Putra_Khamdani_3H_Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt
import requests
from io import BytesIO

# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg","https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg","https://www.newsdone.com/wp-content/uploads/2020/08/cat-british-shorthair-cat-s-eyes-british.jpg"]

# Header dengan User-Agent
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'
}
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
    # Mengunduh gambar dari URL
    response = requests.get(url, headers=headers)
    image = Image.open(BytesIO(response.content))
    # Convert to numpy array
    image = np.array(image)                           #read image
    image = cv.resize(image, (0,0), fx=0.5, fy=0.5)   #resize image to half size
    image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)    #convert color to RGB
    final_frame = cv.hconcat((image, image_2))        #concatenate image
    cv2_imshow(final_frame)                           #show image
    print('\n')

tinggi = image_2.shape[0]
lebar  = image_2.shape[1]
print("resolusi image: tinggi x lebar = ", tinggi, " x ", lebar)
cv2_imshow(image_2)
print('\n')

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

 #membuat garis horizontal ditengah image
for y in range (lebar):
      image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
print('\n')

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

 #membuat garis vertikal ditengah image
for y in range (tinggi):
      image_3[y, int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
print('\n')

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

 # Membuat garis diagonal dari kiri atas ke kanan bawah
cv.line(image_3, (0, 0), (lebar - 1, tinggi - 1), (255, 255, 255), 1)
 # Membuat garis diagonal dari kiri bawah ke kanan atas
cv.line(image_3, (0, tinggi - 1), (lebar - 1, 0), (255, 255, 255), 1)

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
print('\n')

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

 # Menentukan posisi dan ukuran kotak
x_start, y_start = 180, 90  # Menentukan Koordinat
width, height = 100, 100   # Lebar dan tinggi kotak

 # Menggambar kotak dengan pixel putih
image_3[y_start:y_start + height, x_start:x_start + width] = [255, 255, 255]  # Putih


final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
print('\n')

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

panjang_garis = 200

 # Koordinat Y untuk garis horizontal di tengah gambar
y_start = tinggi // 2

 # Koordinat X untuk mulai dan akhir garis
x_start = (lebar - panjang_garis) // 2
x_end = x_start + panjang_garis

 # Menggambar garis horizontal dengan pixel putih dan menggunakan ketebalan garis 2
cv.line(image_3, (x_start, y_start), (x_end, y_start), (255, 255, 255), 2)

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=910x304>
# resolusi image: tinggi x lebar =  304  x  455
# <PIL.Image.Image image mode=RGB size=455x304>
# <PIL.Image.Image image mode=RGB size=910x304>
# <PIL.Image.Image image mode=RGB size=910x304>
# <PIL.Image.Image image mode=RGB size=910x304>
# <PIL.Image.Image image mode=RGB size=910x304>
# <PIL.Image.Image image mode=RGB size=910x304>
